# %%
import numpy as np 
import pandas as pd

# %%
arr = np.array([2,4,3,5,6,6,7,2,8,2,5,9,2,7])

# %%
sum = np.sum(arr)
print(sum)
# Out:
# 68

# %%
length = len(arr)
print(length)
# Out:
# 14

# %%
mean_average = sum / length
print("Average of list numbers : ", mean_average)
# Out:
# Average of list numbers :  4.857142857142857

# %%
sorted_Data = np.short(arr)
print(sorted_Data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sorted_Data = np.short(arr)
#       2 print(sorted_Data)
#
# NameError: name 'np' is not defined
